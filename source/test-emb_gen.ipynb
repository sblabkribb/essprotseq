# %% [markdown]
# #### Setting environments

# %%
import torch, os, gc
import torch.nn as nn
import pandas as pd
import numpy as np
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import confusion_matrix, matthews_corrcoef, accuracy_score,\
f1_score, precision_score, recall_score, roc_auc_score, average_precision_score

# %%
# Set options
embed_ver = ["clstm", "esm2", "bert", "t5"]
comb_ver = ["emb_gen-clstm", "emb_gen-esm2", "emb_gen-bert", "emb_gen-t5"]

# model options
data_path = "../data/"
model_path = f"../model/emb_gen/"
result_path = f"../result/prd-emb_gen/"
os.makedirs(result_path, exist_ok=True)

col_str = ['file_id', 'organism', 'locus_tag', 'ess']

batch_size = 256

# %%
# Set data list for test dataset
ts_data = {
    "data1": ["C018"],  # "Escherichia coli K-12 BW25113"
    "data2": ["C016"],  # "Escherichia coli K-12 MG1655"
    "data3": ["O046"],  # "synthetic bacterium JCVI-Syn3A"
    "data4": ["C048"],  # Bacteroides thetaiotaomicron VPI-5482
    "data5": ["C050"]  # Salmonella enterica subsp. enterica serovar Typhimurium str. 14028S
}

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Define function to record perfomance result
def record_perform(emb_ver, file_id, organ, y_real, y_conf, y_prd):
    y_real = y_real.cpu().numpy()
    y_conf = y_conf.cpu().numpy()
    y_prd = y_prd.cpu().numpy()
    
    if file_id != "O046":
        auc_roc = [roc_auc_score(y_real, y_conf)]
        auc_pr = [average_precision_score(y_real, y_conf)]
    else:
        auc_roc = None
        auc_pr = None
    
    tn, fp, fn, tp = confusion_matrix(y_real, y_prd).ravel()
    
    result = pd.DataFrame({
        "emb": [emb_ver],
        "file": [file_id],
        "organism": [organ],
        "tp": [tp],
        "fp": [fp],
        "tn": [tn],
        "fn": [fn],
        "mcc": [matthews_corrcoef(y_real, y_prd)],
        "acc": [accuracy_score(y_real, y_prd)],
        "f1": [f1_score(y_real, y_prd)],
        "prc": [precision_score(y_real, y_prd)],
        "rec": [recall_score(y_real, y_prd)],
        "npv": [precision_score(1 - y_real, 1 - y_prd)],
        "tnr": [recall_score(1 - y_real, 1 - y_prd)],
        "auc-roc": auc_roc,
        "auc-pr": auc_pr
    })

    return result

# %%
# Set model architecture
class Classifier(nn.Module):
    def __init__(self, input_size, num_layers, unit_decrease):
        super(Classifier, self).__init__()
        layers = [nn.BatchNorm1d(input_size), nn.Dropout(0.5)]
        in_dim = input_size
        out_dim = 1024
        for i in range(num_layers):            
            out_dim = max(2, out_dim // unit_decrease)
            layers.append(nn.Linear(in_dim, out_dim))
            self.initialize_weights(layers[-1])
            layers.append(nn.GELU())
            in_dim = out_dim
        layers.append(nn.Linear(out_dim, 1))
        self.cls_block = nn.Sequential(*layers)
        
    def initialize_weights(self, layer):
        nn.init.kaiming_normal_(layer.weight, mode='fan_in', nonlinearity='linear')
        if layer.bias is not None:
            nn.init.zeros_(layer.bias)
    
    def forward(self, x):
        return self.cls_block(x)

# %% [markdown]
# #### Evaluate model

# %%
df_eval = pd.DataFrame()

for e_ver in embed_ver:
    ver = f'emb_gen-{e_ver}'
    print(f"\n>>>> {ver} <<<<")
    
    if ver in comb_ver:            
        # load dataset
        data = pd.read_csv(data_path + f"data-{ver}-ts.csv")
        display("Raw data:", data)

        #### Preprocess for test dataset ####
        col_num = [col for col in data.columns if col not in col_str]

        # get test datasets
        loc_ts = {}
        data_ts = {}
        org_ts = {}
        for ts_ver, ids in ts_data.items():
            # get test sample locations
            loc_ts[ts_ver] = data['file_id'].isin(ids)
            # get test samples
            data_ts[ts_ver] = data[loc_ts[ts_ver]]
            org = []
            # get test organism list
            for i in ids:
                organ = data_ts[ts_ver]['organism'][data_ts[ts_ver]['file_id'] == i].to_list()
                if len(organ) > 0:
                    org.append(organ[0])
            org_ts[ts_ver] = org

            print("Test dataset(" + ts_ver + "):", data_ts[ts_ver].shape)
        print("Test organism:", org_ts, len(org_ts))

        # split info.& inputs & labels of the test datasets
        info_ts = {}
        y_ts = {}
        test_loader = {}
        for ts_ver, df in data_ts.items():
            info_ts[ts_ver] = df[col_str]
            X_ts = torch.tensor(df[col_num].astype('float32').values)
            y_ts[ts_ver] = torch.tensor(df['ess'].astype('float32').values)
            print("Splited test dataset(" + ts_ver + "):", X_ts.shape, y_ts[ts_ver].shape)                    
            # generate dataloader by the test datasets
            dataset_ts = TensorDataset(X_ts, y_ts[ts_ver])
            test_loader[ts_ver] = DataLoader(dataset_ts, batch_size=batch_size, shuffle=False)

        # get the total test dataset
        loc_ts_all = [sum(loc) >= 1 for loc in zip(*loc_ts.values())]
        info_ts_all = data.loc[loc_ts_all, col_str]
        X_ts_all = torch.tensor(data.loc[loc_ts_all, col_num].astype('float32').values)
        y_ts_all = torch.tensor(data.loc[loc_ts_all, 'ess'].astype('float32').values)
        
        print("Splited test dataset(all):", X_ts_all.shape, y_ts_all.shape)

        # generate dataloader of total test dataset
        test_all_dataset = TensorDataset(X_ts_all, y_ts_all)
        test_all_loader = DataLoader(test_all_dataset, batch_size=batch_size, shuffle=False)
        

        #### Evaluate model ####
        # set model name
        model_name = f"{ver}-{fcnn_ver}"
        print(f"\n===== Test model: {model_name} ====")
        # generate model instance
        model = Classifier(
            input_size=X_ts_all.shape[-1],
            num_layers=3,
            unit_decrease=2
        ).to(device)

        # load model weight
        model.load_state_dict(torch.load(model_path + model_name + ".pt", map_location=device))
        model.eval()


        ## model evaluations by test dataset ##
        for ts_ver, ids in ts_data.items():
            all_preds = []
            all_labels = []
            with torch.no_grad():
                for X_batch, y_batch in test_loader[ts_ver]:
                    X_batch = X_batch.to(device)
                    y_batch = y_batch.to(device)
                    preds = model(X_batch).squeeze()
                    all_preds.append(preds.cpu())
                    all_labels.append(y_batch.cpu())
            
            # concatenate results to one tensor
            all_preds = torch.cat(all_preds)
            all_labels = torch.cat(all_labels)

            # convert logits to confidences & classes
            prd_conf = torch.sigmoid(all_preds)
            prd_cls = (prd_conf >= 0.5).int()
            # performances by testset
            perform = record_perform(
                emb_ver=e_ver,
                file_id="+".join(ids),
                organ="+".join(org_ts[ts_ver]),
                y_real=y_ts[ts_ver],
                y_conf=prd_conf,
                y_prd=prd_cls,
            )
            display(perform)
            df_eval = pd.concat([df_eval, perform], ignore_index=True)
        
        
        ## model evaluation on the total test dataset ##
        all_preds = []
        all_labels = []
        with torch.no_grad():
            for X_batch, y_batch in test_all_loader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                preds = model(X_batch).squeeze()
                all_preds.append(preds.cpu())
                all_labels.append(y_batch.cpu())
        
        # concatenate results to one tensor
        all_preds = torch.cat(all_preds)
        all_labels = torch.cat(all_labels)

        # convert logits to confidences & classes
        prd_conf = torch.sigmoid(all_preds)
        prd_cls = (prd_conf >= 0.5).int()

        # performances on total testset
        perform = record_perform(
            emb_ver=e_ver,
            file_id="+".join([i for ids in ts_data.values() for i in ids]),
            organ="+".join([org for orgs in org_ts.values() for org in orgs]),
            y_real=y_ts_all,
            y_conf=prd_conf,
            y_prd=prd_cls
        )
        display(perform)
        df_eval = pd.concat([df_eval, perform], ignore_index=True)

        # concatenate the protein info. & predicted confidences
        df_prd = pd.DataFrame(prd_conf, columns=["conf"], index=info_ts_all.index)
        df_prd = pd.concat([info_ts_all, df_prd], axis=1)

        # save the model prediction result
        df_prd.to_csv(result_path + f"prd-{model_name}.csv", index=False)

        gc.collect()

# save the model perfomance result
display("Model performance:", df_eval)
df_eval.to_csv(f"../result/eval-emb_gen.csv", index=False)
# Out:
# >>>> emb_gen-clstm <<<<
# 'Raw data:'
#       file_id                                           organism  \
# 0        C050  Salmonella enterica subsp. enterica serovar Ty...
# 1        C050  Salmonella enterica subsp. enterica serovar Ty...
# 2        C050  Salmonella enterica subsp. enterica serovar Ty...
# 3        C050  Salmonella enterica subsp. enterica serovar Ty...
# 4        C050  Salmonella enterica subsp. enterica serovar Ty...
# ...       ...                                                ...
# 19378    O046                     synthetic bacterium JCVI-Syn3A
# 19379    O046                     synthetic bacterium JCVI-Syn3A
# 19380    O046                     synthetic bacterium JCVI-Syn3A
# 19381    O046                     synthetic bacterium JCVI-Syn3A
# 19382    O046                     synthetic bacterium JCVI-Syn3A
#
#             locus_tag  ess         0         1         2         3         4  \
# 0          STM14_0001    0 -1.271414  0.000099  0.076290 -0.000540 -0.002149
# 1          STM14_0002    0  0.080849  0.000191  0.066948 -0.001360 -0.001139
# 2          STM14_0003    0  0.049742  0.000037  0.063013 -0.003911 -0.002671
# 3          STM14_0004    0  0.438240  0.000130  0.061992 -0.002766 -0.001883
# 4          STM14_0005    0  0.647014  0.000091  0.058150 -0.003637 -0.002623
# ...               ...  ...       ...       ...       ...       ...       ...
# 19378  JCVISYN3A_0913    1  0.244533  0.000047  0.060919 -0.003986 -0.002723
# 19379  JCVISYN3A_0918    1  0.446268  0.000114  0.060191 -0.002962 -0.002494
# 19380  JCVISYN3A_0930    1 -1.313249  0.000093  0.077817 -0.000610 -0.002145
# 19381  JCVISYN3A_0931    1  0.339057  0.000057  0.060354 -0.003875 -0.002801
# 19382  JCVISYN3A_0932    1 -0.883009  0.000164  0.072825 -0.000142 -0.002015
#
#               5  ...      1014      1015      1016      1017      1018  \
# 0     -0.002770  ... -0.000128  0.004823  0.000413  0.127032  0.006706
# 1     -0.002485  ... -0.000043  0.001776  0.001967  0.126776  0.007055
# 2     -0.000340  ... -0.000037  0.001271  0.002466  0.126992  0.007107
# 3     -0.001800  ... -0.000041  0.001173  0.001617  0.127110  0.007114
# 4     -0.002049  ... -0.000028  0.000526  0.001174  0.127482  0.007209
# ...         ...  ...       ...       ...       ...       ...       ...
# 19378 -0.000765  ... -0.000052  0.001888  0.002917  0.127124  0.007069
# 19379 -0.002787  ... -0.000028  0.001444  0.000616  0.126796  0.007066
# 19380 -0.002522  ... -0.000083  0.002701  0.002104  0.127490  0.007041
# 19381 -0.001344  ... -0.000051  0.000935  0.001868  0.126976  0.007136
# 19382 -0.004417  ... -0.000059  0.002321  0.003451  0.127408  0.007078
#
#            1019      1020      1021      1022      1023
# 0      0.013683 -0.020618 -0.049667  0.108772 -0.003629
# 1      0.008662  0.113034 -0.035381  0.105291  0.002070
# 2      0.007993  0.119393 -0.034128  0.103778  0.002723
# 3      0.008159  0.119812 -0.033128  0.105875  0.002058
# 4      0.007493  0.129736 -0.029263  0.105677  0.004036
# ...         ...       ...       ...       ...       ...
# 19378  0.007943  0.102165 -0.032948  0.106551  0.001652
# 19379  0.008400  0.101383 -0.035993  0.105889  0.002418
# 19380  0.009210  0.034684 -0.041377  0.106090 -0.001276
# 19381  0.007776  0.122922 -0.030382  0.105050  0.003196
# 19382  0.008844  0.051645 -0.038606  0.106487  0.000233
#
# [19383 rows x 1028 columns]
# Test dataset(data1): (4313, 1028)
# Test dataset(data2): (4313, 1028)
# Test dataset(data3): (458, 1028)
# Test dataset(data4): (4825, 1028)
# Test dataset(data5): (5474, 1028)
# Test organism: {'data1': ['Escherichia coli K-12 BW25113'], 'data2': ['Escherichia coli K-12 MG1655'], 'data3': ['synthetic bacterium JCVI-Syn3A'], 'data4': ['Bacteroides thetaiotaomicron VPI-5482'], 'data5': ['Salmonella enterica subsp. enterica serovar Typhimurium str. 14028S']} 5
# Splited test dataset(data1): torch.Size([4313, 1024]) torch.Size([4313])
# Splited test dataset(data2): torch.Size([4313, 1024]) torch.Size([4313])
# Splited test dataset(data3): torch.Size([458, 1024]) torch.Size([458])
# Splited test dataset(data4): torch.Size([4825, 1024]) torch.Size([4825])
# Splited test dataset(data5): torch.Size([5474, 1024]) torch.Size([5474])
# Splited test dataset(all): torch.Size([19383, 1024]) torch.Size([19383])
#
# ===== Test model: emb_gen-clstm-3_2 ====
# /tmp/ipykernel_7278/1828744696.py:73: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path + model_name + ".pt", map_location=device))
#      emb fcnn testset  file                       organism   tp   fp    tn  \
# 0  clstm  3_2   data1  C018  Escherichia coli K-12 BW25113  233  229  3786
#
#    fn       mcc       acc        f1       prc       rec       npv       tnr  \
# 0  65  0.594411  0.931834  0.613158  0.504329  0.781879  0.983121  0.942964
#
#     auc-roc    auc-pr
# 0  0.910965  0.586572
#      emb fcnn testset  file                      organism   tp   fp    tn  fn  \
# 0  clstm  3_2   data2  C016  Escherichia coli K-12 MG1655  241  240  3783  49
#
#         mcc       acc        f1      prc       rec       npv       tnr  \
# 0  0.613699  0.932993  0.625162  0.50104  0.831034  0.987213  0.940343
#
#     auc-roc    auc-pr
# 0  0.947629  0.632228
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#      emb fcnn testset  file                        organism   tp  fp  tn   fn  \
# 0  clstm  3_2   data3  O046  synthetic bacterium JCVI-Syn3A  112   0   0  346
#
#    mcc       acc        f1  prc       rec  npv  tnr auc-roc auc-pr
# 0  0.0  0.244541  0.392982  1.0  0.244541  0.0  0.0    None   None
# /tmp/ipykernel_7278/1828744696.py:108: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_eval = pd.concat([df_eval, perform], ignore_index=True)
#      emb fcnn testset  file                               organism   tp   fp  \
# 0  clstm  3_2   data4  C048  Bacteroides thetaiotaomicron VPI-5482  282  107
#
#      tn  fn       mcc       acc        f1       prc       rec       npv  \
# 0  4393  43  0.776919  0.968912  0.789916  0.724936  0.867692  0.990307
#
#         tnr   auc-roc    auc-pr
# 0  0.976222  0.975421  0.818815
#      emb fcnn testset  file  \
# 0  clstm  3_2   data5  C050
#
#                                             organism  tp   fp    tn  fn  \
# 0  Salmonella enterica subsp. enterica serovar Ty...  78  493  4868  35
#
#         mcc       acc       f1       prc       rec       npv      tnr  \
# 0  0.278314  0.903544  0.22807  0.136602  0.690265  0.992862  0.90804
#
#     auc-roc    auc-pr
# 0  0.891886  0.107095
#      emb fcnn   testset                      file  \
# 0  clstm  3_2  test_all  C018+C016+O046+C048+C050
#
#                                             organism   tp    fp     tn   fn  \
# 0  Escherichia coli K-12 BW25113+Escherichia coli...  946  1069  16830  538
#
#        mcc       acc        f1       prc       rec       npv       tnr  \
# 0  0.50333  0.917092  0.540726  0.469479  0.637466  0.969023  0.940276
#
#     auc-roc    auc-pr
# 0  0.883538  0.461305
# >>>> emb_gen-esm2 <<<<
# 'Raw data:'
#       file_id                                           organism  \
# 0        C050  Salmonella enterica subsp. enterica serovar Ty...
# 1        C050  Salmonella enterica subsp. enterica serovar Ty...
# 2        C050  Salmonella enterica subsp. enterica serovar Ty...
# 3        C050  Salmonella enterica subsp. enterica serovar Ty...
# 4        C050  Salmonella enterica subsp. enterica serovar Ty...
# ...       ...                                                ...
# 19378    O046                     synthetic bacterium JCVI-Syn3A
# 19379    O046                     synthetic bacterium JCVI-Syn3A
# 19380    O046                     synthetic bacterium JCVI-Syn3A
# 19381    O046                     synthetic bacterium JCVI-Syn3A
# 19382    O046                     synthetic bacterium JCVI-Syn3A
#
#             locus_tag  ess         0         1         2         3         4  \
# 0          STM14_0001    0 -0.025803  2.423989 -1.412047 -0.427782  2.635565
# 1          STM14_0002    0 -0.668316 -0.463429  0.103198 -0.088451  0.004220
# 2          STM14_0003    0 -0.389958 -0.056299  0.404185 -0.130026  0.101402
# 3          STM14_0004    0 -0.132498 -0.263630  0.180769 -0.201304 -0.002199
# 4          STM14_0005    0 -0.286661 -0.111691  0.556191 -0.063293 -0.274769
# ...               ...  ...       ...       ...       ...       ...       ...
# 19378  JCVISYN3A_0913    1 -0.013360 -0.466237 -0.574799  0.004326 -0.280262
# 19379  JCVISYN3A_0918    1 -0.644403 -0.233777  0.404386  0.101492 -0.407517
# 19380  JCVISYN3A_0930    1  0.311929 -0.638465  0.265130  0.334715  1.060847
# 19381  JCVISYN3A_0931    1 -0.985561  0.844931 -0.040269 -0.267429 -0.631806
# 19382  JCVISYN3A_0932    1 -0.401236  0.248233  0.147316  0.289595  1.225728
#
#               5  ...      1270      1271      1272      1273      1274  \
# 0     -0.527033  ... -0.155313  1.499200 -1.622623  1.140054 -0.579188
# 1      0.314487  ... -0.441345 -0.216852 -0.173726  0.456722 -0.253636
# 2      0.399542  ... -0.291001 -0.496596 -0.240145  0.931340  0.250903
# 3      0.342121  ...  0.079341 -0.345971 -0.169741  0.699338 -0.327057
# 4      0.401593  ...  0.157999 -0.030111  0.223549  1.058194 -0.627709
# ...         ...  ...       ...       ...       ...       ...       ...
# 19378  0.498790  ... -0.052086 -0.375514 -0.349227  1.061728 -0.046756
# 19379  0.367913  ... -0.216774 -0.193204 -0.085630  0.603998  0.047384
# 19380  0.648867  ... -0.729781 -0.557699 -0.633800  0.923602 -1.082554
# 19381 -0.615640  ...  0.835866 -0.616349 -0.738524 -0.103508  0.191622
# 19382  0.659449  ... -0.861169 -0.379896 -0.889800  1.496078 -0.855529
#
#            1275      1276      1277      1278      1279
# 0     -0.201200 -0.181841  2.446096  1.391733 -0.146903
# 1      0.488008 -0.237100  0.032918 -0.110359  0.293158
# 2      0.500919 -0.206658  0.055057  0.349885  0.051546
# 3      0.669865 -0.155763  0.371676 -0.280873 -0.052240
# 4     -0.035077  0.126186  0.007433 -0.104928 -0.069931
# ...         ...       ...       ...       ...       ...
# 19378  0.376358  0.299031  0.954350  1.110562  0.166870
# 19379  0.273780  0.067045 -0.170716  0.290532  0.482953
# 19380  0.885507 -1.106922 -1.015008 -0.201546 -0.682305
# 19381  0.856668 -0.864706  0.502746  0.409977  0.147629
# 19382  0.104069 -0.037691  0.230196  0.462017 -0.631379
#
# [19383 rows x 1284 columns]
# Test dataset(data1): (4313, 1284)
# Test dataset(data2): (4313, 1284)
# Test dataset(data3): (458, 1284)
# Test dataset(data4): (4825, 1284)
# Test dataset(data5): (5474, 1284)
# Test organism: {'data1': ['Escherichia coli K-12 BW25113'], 'data2': ['Escherichia coli K-12 MG1655'], 'data3': ['synthetic bacterium JCVI-Syn3A'], 'data4': ['Bacteroides thetaiotaomicron VPI-5482'], 'data5': ['Salmonella enterica subsp. enterica serovar Typhimurium str. 14028S']} 5
# Splited test dataset(data1): torch.Size([4313, 1280]) torch.Size([4313])
# Splited test dataset(data2): torch.Size([4313, 1280]) torch.Size([4313])
# Splited test dataset(data3): torch.Size([458, 1280]) torch.Size([458])
# Splited test dataset(data4): torch.Size([4825, 1280]) torch.Size([4825])
# Splited test dataset(data5): torch.Size([5474, 1280]) torch.Size([5474])
# Splited test dataset(all): torch.Size([19383, 1280]) torch.Size([19383])
#
# ===== Test model: emb_gen-esm2-3_2 ====
# /tmp/ipykernel_7278/1828744696.py:73: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path + model_name + ".pt", map_location=device))
#     emb fcnn testset  file                       organism   tp   fp    tn  fn  \
# 0  esm2  3_2   data1  C018  Escherichia coli K-12 BW25113  269  519  3496  29
#
#         mcc       acc        f1       prc       rec       npv       tnr  \
# 0  0.507602  0.872942  0.495396  0.341371  0.902685  0.991773  0.870735
#
#     auc-roc    auc-pr
# 0  0.942126  0.701041
#     emb fcnn testset  file                      organism   tp   fp    tn  fn  \
# 0  esm2  3_2   data2  C016  Escherichia coli K-12 MG1655  280  517  3506  10
#
#         mcc       acc        f1       prc       rec       npv       tnr  \
# 0  0.540069  0.877811  0.515179  0.351317  0.965517  0.997156  0.871489
#
#    auc-roc    auc-pr
# 0   0.9755  0.784774
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#     emb fcnn testset  file                        organism   tp  fp  tn   fn  \
# 0  esm2  3_2   data3  O046  synthetic bacterium JCVI-Syn3A  259   0   0  199
#
#    mcc       acc        f1  prc       rec  npv  tnr auc-roc auc-pr
# 0  0.0  0.565502  0.722455  1.0  0.565502  0.0  0.0    None   None
# /tmp/ipykernel_7278/1828744696.py:108: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_eval = pd.concat([df_eval, perform], ignore_index=True)
#     emb fcnn testset  file                               organism   tp   fp  \
# 0  esm2  3_2   data4  C048  Bacteroides thetaiotaomicron VPI-5482  292  622
#
#      tn  fn       mcc       acc        f1       prc       rec       npv  \
# 0  3878  33  0.486274  0.864249  0.471348  0.319475  0.898462  0.991562
#
#         tnr   auc-roc    auc-pr
# 0  0.861778  0.937444  0.613368
#     emb fcnn testset  file                                           organism  \
# 0  esm2  3_2   data5  C050  Salmonella enterica subsp. enterica serovar Ty...
#
#    tp   fp    tn  fn       mcc       acc        f1       prc       rec  \
# 0  65  688  4673  48  0.184478  0.865546  0.150115  0.086321  0.575221
#
#         npv       tnr   auc-roc    auc-pr
# 0  0.989833  0.871666  0.832666  0.062933
#     emb fcnn   testset                      file  \
# 0  esm2  3_2  test_all  C018+C016+O046+C048+C050
#
#                                             organism    tp    fp     tn   fn  \
# 0  Escherichia coli K-12 BW25113+Escherichia coli...  1165  2346  15553  319
#
#         mcc       acc        f1       prc      rec       npv       tnr  \
# 0  0.451501  0.862508  0.466466  0.331814  0.78504  0.979902  0.868931
#
#     auc-roc   auc-pr
# 0  0.894743  0.48336
# >>>> emb_gen-bert <<<<
# 'Raw data:'
#       file_id                                           organism  \
# 0        C050  Salmonella enterica subsp. enterica serovar Ty...
# 1        C050  Salmonella enterica subsp. enterica serovar Ty...
# 2        C050  Salmonella enterica subsp. enterica serovar Ty...
# 3        C050  Salmonella enterica subsp. enterica serovar Ty...
# 4        C050  Salmonella enterica subsp. enterica serovar Ty...
# ...       ...                                                ...
# 19378    O046                     synthetic bacterium JCVI-Syn3A
# 19379    O046                     synthetic bacterium JCVI-Syn3A
# 19380    O046                     synthetic bacterium JCVI-Syn3A
# 19381    O046                     synthetic bacterium JCVI-Syn3A
# 19382    O046                     synthetic bacterium JCVI-Syn3A
#
#             locus_tag  ess         0         1         2         3         4  \
# 0          STM14_0001    0  0.042822 -0.126205 -0.050820 -0.129861  0.068868
# 1          STM14_0002    0 -0.058692 -0.037950 -0.004752  0.014216 -0.023279
# 2          STM14_0003    0 -0.070625 -0.035552  0.038030  0.001899 -0.000246
# 3          STM14_0004    0 -0.037140 -0.036069  0.029161  0.002461 -0.011851
# 4          STM14_0005    0 -0.032631 -0.024123 -0.018862  0.039874 -0.006922
# ...               ...  ...       ...       ...       ...       ...       ...
# 19378  JCVISYN3A_0913    1 -0.036090 -0.011721 -0.002769  0.041671  0.005540
# 19379  JCVISYN3A_0918    1 -0.023218 -0.008702  0.014693  0.022481  0.036286
# 19380  JCVISYN3A_0930    1 -0.009309  0.004102  0.003444  0.031261  0.026689
# 19381  JCVISYN3A_0931    1  0.007387 -0.008439  0.020698  0.009457  0.050447
# 19382  JCVISYN3A_0932    1 -0.003982 -0.006275 -0.016097  0.000110  0.054206
#
#               5  ...      1014      1015      1016      1017      1018  \
# 0     -0.006040  ... -0.013456 -0.048067 -0.110174 -0.008105  0.018130
# 1      0.035774  ...  0.007268 -0.119998  0.003547 -0.041535 -0.139431
# 2      0.004621  ... -0.001732 -0.167638 -0.040140 -0.074581 -0.179380
# 3      0.017077  ...  0.032899 -0.134339  0.000210 -0.057801 -0.168538
# 4     -0.055323  ...  0.046949 -0.040834 -0.021078 -0.029033 -0.105917
# ...         ...  ...       ...       ...       ...       ...       ...
# 19378  0.003676  ... -0.005665 -0.128913  0.003729 -0.027293 -0.126274
# 19379  0.010613  ...  0.056558 -0.047529 -0.022225 -0.060193 -0.078188
# 19380  0.051066  ...  0.051691 -0.034478  0.004822  0.016618  0.070800
# 19381 -0.007523  ...  0.059217 -0.071523  0.001269 -0.009234 -0.043703
# 19382  0.020400  ...  0.058493 -0.022661 -0.013347  0.014802  0.045168
#
#            1019      1020      1021      1022      1023
# 0     -0.105259 -0.008767  0.005277  0.042083  0.034597
# 1      0.001130 -0.025769 -0.031517  0.014989 -0.006627
# 2     -0.021140 -0.023059 -0.046827  0.031335 -0.032964
# 3     -0.000947 -0.042856 -0.030568  0.011087 -0.040674
# 4      0.012200  0.013685 -0.042306 -0.009481 -0.002596
# ...         ...       ...       ...       ...       ...
# 19378 -0.013166 -0.049804 -0.017025 -0.028457 -0.000095
# 19379 -0.036799 -0.024342 -0.014599  0.013637 -0.009223
# 19380  0.009008 -0.033036 -0.031658 -0.041180 -0.027903
# 19381  0.003266 -0.027528 -0.026730 -0.012166  0.000853
# 19382  0.007664 -0.043993 -0.020068 -0.042839 -0.003225
#
# [19383 rows x 1028 columns]
# Test dataset(data1): (4313, 1028)
# Test dataset(data2): (4313, 1028)
# Test dataset(data3): (458, 1028)
# Test dataset(data4): (4825, 1028)
# Test dataset(data5): (5474, 1028)
# Test organism: {'data1': ['Escherichia coli K-12 BW25113'], 'data2': ['Escherichia coli K-12 MG1655'], 'data3': ['synthetic bacterium JCVI-Syn3A'], 'data4': ['Bacteroides thetaiotaomicron VPI-5482'], 'data5': ['Salmonella enterica subsp. enterica serovar Typhimurium str. 14028S']} 5
# Splited test dataset(data1): torch.Size([4313, 1024]) torch.Size([4313])
# Splited test dataset(data2): torch.Size([4313, 1024]) torch.Size([4313])
# Splited test dataset(data3): torch.Size([458, 1024]) torch.Size([458])
# Splited test dataset(data4): torch.Size([4825, 1024]) torch.Size([4825])
# Splited test dataset(data5): torch.Size([5474, 1024]) torch.Size([5474])
# Splited test dataset(all): torch.Size([19383, 1024]) torch.Size([19383])
#
# ===== Test model: emb_gen-bert-3_2 ====
# /tmp/ipykernel_7278/1828744696.py:73: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path + model_name + ".pt", map_location=device))
#     emb fcnn testset  file                       organism   tp   fp    tn  fn  \
# 0  bert  3_2   data1  C018  Escherichia coli K-12 BW25113  270  430  3585  28
#
#         mcc       acc        f1       prc      rec      npv       tnr  \
# 0  0.549519  0.893809  0.541082  0.385714  0.90604  0.99225  0.892902
#
#     auc-roc    auc-pr
# 0  0.950126  0.758463
#     emb fcnn testset  file                      organism   tp   fp    tn  fn  \
# 0  bert  3_2   data2  C016  Escherichia coli K-12 MG1655  282  440  3583   8
#
#         mcc       acc        f1       prc       rec       npv       tnr  \
# 0  0.578935  0.896128  0.557312  0.390582  0.972414  0.997772  0.890629
#
#     auc-roc    auc-pr
# 0  0.980791  0.839553
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#     emb fcnn testset  file                        organism   tp  fp  tn   fn  \
# 0  bert  3_2   data3  O046  synthetic bacterium JCVI-Syn3A  283   0   0  175
#
#    mcc       acc        f1  prc       rec  npv  tnr auc-roc auc-pr
# 0  0.0  0.617904  0.763833  1.0  0.617904  0.0  0.0    None   None
# /tmp/ipykernel_7278/1828744696.py:108: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_eval = pd.concat([df_eval, perform], ignore_index=True)
#     emb fcnn testset  file                               organism   tp   fp  \
# 0  bert  3_2   data4  C048  Bacteroides thetaiotaomicron VPI-5482  219  617
#
#      tn   fn       mcc       acc        f1       prc       rec       npv  \
# 0  3883  106  0.355445  0.850155  0.377261  0.261962  0.673846  0.973427
#
#         tnr   auc-roc    auc-pr
# 0  0.862889  0.851592  0.484393
#     emb fcnn testset  file                                           organism  \
# 0  bert  3_2   data5  C050  Salmonella enterica subsp. enterica serovar Ty...
#
#    tp   fp    tn  fn       mcc       acc        f1       prc       rec  \
# 0  39  730  4631  74  0.085505  0.853124  0.088435  0.050715  0.345133
#
#         npv       tnr   auc-roc    auc-pr
# 0  0.984272  0.863831  0.717901  0.042231
#     emb fcnn   testset                      file  \
# 0  bert  3_2  test_all  C018+C016+O046+C048+C050
#
#                                             organism    tp    fp     tn   fn  \
# 0  Escherichia coli K-12 BW25113+Escherichia coli...  1093  2217  15682  391
#
#         mcc       acc        f1       prc       rec       npv       tnr  \
# 0  0.432902  0.865449  0.455987  0.330211  0.736523  0.975673  0.876138
#
#     auc-roc    auc-pr
# 0  0.880059  0.490736
# >>>> emb_gen-t5 <<<<
# 'Raw data:'
#       file_id                                           organism  \
# 0        C050  Salmonella enterica subsp. enterica serovar Ty...
# 1        C050  Salmonella enterica subsp. enterica serovar Ty...
# 2        C050  Salmonella enterica subsp. enterica serovar Ty...
# 3        C050  Salmonella enterica subsp. enterica serovar Ty...
# 4        C050  Salmonella enterica subsp. enterica serovar Ty...
# ...       ...                                                ...
# 19378    O046                     synthetic bacterium JCVI-Syn3A
# 19379    O046                     synthetic bacterium JCVI-Syn3A
# 19380    O046                     synthetic bacterium JCVI-Syn3A
# 19381    O046                     synthetic bacterium JCVI-Syn3A
# 19382    O046                     synthetic bacterium JCVI-Syn3A
#
#             locus_tag  ess         0         1         2         3         4  \
# 0          STM14_0001    0  0.018239 -0.030508  0.078645  0.082283  0.127463
# 1          STM14_0002    0  0.043340  0.078926  0.026737  0.050184  0.004291
# 2          STM14_0003    0  0.083051  0.047820  0.007012  0.029369 -0.004415
# 3          STM14_0004    0  0.048851  0.071860  0.020825  0.042091 -0.002787
# 4          STM14_0005    0  0.035259  0.042339  0.024604 -0.025343 -0.006228
# ...               ...  ...       ...       ...       ...       ...       ...
# 19378  JCVISYN3A_0913    1  0.020563  0.107576  0.027025  0.052937 -0.012762
# 19379  JCVISYN3A_0918    1  0.057506 -0.014071 -0.033472  0.067503 -0.016533
# 19380  JCVISYN3A_0930    1  0.003938 -0.011171  0.027588  0.017686 -0.010909
# 19381  JCVISYN3A_0931    1  0.064550  0.037385 -0.023904 -0.001969 -0.006216
# 19382  JCVISYN3A_0932    1  0.014697 -0.015697  0.002884  0.031844  0.026725
#
#               5  ...      1014      1015      1016      1017      1018  \
# 0     -0.197618  ...  0.027051  0.021510  0.231686 -0.173741  0.079085
# 1      0.038041  ... -0.023108 -0.003255 -0.010074 -0.010509  0.021057
# 2      0.054288  ... -0.021937 -0.035736  0.000474 -0.025479  0.003724
# 3      0.009612  ...  0.005614 -0.032511 -0.037446 -0.013102  0.030071
# 4      0.043092  ... -0.020996  0.023913 -0.012189 -0.067514  0.045659
# ...         ...  ...       ...       ...       ...       ...       ...
# 19378  0.021742  ...  0.013594  0.028046  0.010028 -0.060973  0.093713
# 19379  0.091051  ... -0.048624  0.031121  0.011467 -0.048133 -0.033131
# 19380  0.041780  ... -0.008057  0.051703  0.032014 -0.148301  0.106521
# 19381  0.048084  ... -0.037994 -0.018542 -0.014736 -0.102566  0.023649
# 19382  0.016438  ... -0.035644  0.047650  0.034557 -0.138713  0.020779
#
#            1019      1020      1021      1022      1023
# 0     -0.236435 -0.114395  0.054386 -0.030780 -0.075774
# 1     -0.041092 -0.026289  0.020529 -0.029514  0.032310
# 2     -0.044224 -0.078591 -0.024167 -0.032960 -0.003994
# 3      0.009861 -0.022703 -0.002080 -0.011043  0.036730
# 4      0.010079 -0.014732 -0.013761 -0.029590  0.063286
# ...         ...       ...       ...       ...       ...
# 19378 -0.003019 -0.053488 -0.045007 -0.043997 -0.002393
# 19379 -0.060800 -0.055844 -0.098644 -0.041724  0.014361
# 19380 -0.029680 -0.032345 -0.021705  0.096927  0.099435
# 19381 -0.022915 -0.034404 -0.085372  0.044055  0.009911
# 19382  0.001969 -0.025202 -0.004286  0.075814  0.085440
#
# [19383 rows x 1028 columns]
# Test dataset(data1): (4313, 1028)
# Test dataset(data2): (4313, 1028)
# Test dataset(data3): (458, 1028)
# Test dataset(data4): (4825, 1028)
# Test dataset(data5): (5474, 1028)
# Test organism: {'data1': ['Escherichia coli K-12 BW25113'], 'data2': ['Escherichia coli K-12 MG1655'], 'data3': ['synthetic bacterium JCVI-Syn3A'], 'data4': ['Bacteroides thetaiotaomicron VPI-5482'], 'data5': ['Salmonella enterica subsp. enterica serovar Typhimurium str. 14028S']} 5
# Splited test dataset(data1): torch.Size([4313, 1024]) torch.Size([4313])
# Splited test dataset(data2): torch.Size([4313, 1024]) torch.Size([4313])
# Splited test dataset(data3): torch.Size([458, 1024]) torch.Size([458])
# Splited test dataset(data4): torch.Size([4825, 1024]) torch.Size([4825])
# Splited test dataset(data5): torch.Size([5474, 1024]) torch.Size([5474])
# Splited test dataset(all): torch.Size([19383, 1024]) torch.Size([19383])
#
# ===== Test model: emb_gen-t5-3_2 ====
# /tmp/ipykernel_7278/1828744696.py:73: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path + model_name + ".pt", map_location=device))
#   emb fcnn testset  file                       organism   tp   fp    tn  fn  \
# 0  t5  3_2   data1  C018  Escherichia coli K-12 BW25113  269  372  3643  29
#
#         mcc       acc       f1       prc       rec       npv       tnr  \
# 0  0.577528  0.907025  0.57295  0.419657  0.902685  0.992102  0.907347
#
#    auc-roc    auc-pr
# 0  0.94759  0.696496
#   emb fcnn testset  file                      organism   tp   fp    tn  fn  \
# 0  t5  3_2   data2  C016  Escherichia coli K-12 MG1655  283  369  3654   7
#
#         mcc       acc        f1       prc       rec       npv       tnr  \
# 0  0.618118  0.912822  0.600849  0.434049  0.975862  0.998088  0.908277
#
#     auc-roc    auc-pr
# 0  0.981808  0.825065
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#   emb fcnn testset  file                        organism   tp  fp  tn   fn  \
# 0  t5  3_2   data3  O046  synthetic bacterium JCVI-Syn3A  305   0   0  153
#
#    mcc       acc        f1  prc       rec  npv  tnr auc-roc auc-pr
# 0  0.0  0.665939  0.799476  1.0  0.665939  0.0  0.0    None   None
# /tmp/ipykernel_7278/1828744696.py:108: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_eval = pd.concat([df_eval, perform], ignore_index=True)
#   emb fcnn testset  file                               organism   tp   fp  \
# 0  t5  3_2   data4  C048  Bacteroides thetaiotaomicron VPI-5482  257  529
#
#      tn  fn       mcc       acc        f1       prc       rec       npv  \
# 0  3971  68  0.456933  0.876269  0.462646  0.326972  0.790769  0.983164
#
#         tnr   auc-roc    auc-pr
# 0  0.882444  0.918049  0.616563
#   emb fcnn testset  file                                           organism  \
# 0  t5  3_2   data5  C050  Salmonella enterica subsp. enterica serovar Ty...
#
#    tp   fp    tn  fn       mcc       acc    f1       prc       rec       npv  \
# 0  36  651  4710  77  0.084616  0.867008  0.09  0.052402  0.318584  0.983915
#
#         tnr   auc-roc    auc-pr
# 0  0.878567  0.781696  0.047115
#   emb fcnn   testset                      file  \
# 0  t5  3_2  test_all  C018+C016+O046+C048+C050
#
#                                             organism    tp    fp     tn   fn  \
# 0  Escherichia coli K-12 BW25113+Escherichia coli...  1150  1921  15978  334
#
#         mcc       acc       f1       prc       rec       npv       tnr  \
# 0  0.486138  0.883661  0.50494  0.374471  0.774933  0.979524  0.892676
#
#     auc-roc    auc-pr
# 0  0.900482  0.525443
# 'Model performance:'
#       emb fcnn   testset                      file  \
# 0   clstm  3_2     data1                      C018
# 1   clstm  3_2     data2                      C016
# 2   clstm  3_2     data3                      O046
# 3   clstm  3_2     data4                      C048
# 4   clstm  3_2     data5                      C050
# 5   clstm  3_2  test_all  C018+C016+O046+C048+C050
# 6    esm2  3_2     data1                      C018
# 7    esm2  3_2     data2                      C016
# 8    esm2  3_2     data3                      O046
# 9    esm2  3_2     data4                      C048
# 10   esm2  3_2     data5                      C050
# 11   esm2  3_2  test_all  C018+C016+O046+C048+C050
# 12   bert  3_2     data1                      C018
# 13   bert  3_2     data2                      C016
# 14   bert  3_2     data3                      O046
# 15   bert  3_2     data4                      C048
# 16   bert  3_2     data5                      C050
# 17   bert  3_2  test_all  C018+C016+O046+C048+C050
# 18     t5  3_2     data1                      C018
# 19     t5  3_2     data2                      C016
# 20     t5  3_2     data3                      O046
# 21     t5  3_2     data4                      C048
# 22     t5  3_2     data5                      C050
# 23     t5  3_2  test_all  C018+C016+O046+C048+C050
#
#                                              organism    tp    fp     tn   fn  \
# 0                       Escherichia coli K-12 BW25113   233   229   3786   65
# 1                        Escherichia coli K-12 MG1655   241   240   3783   49
# 2                      synthetic bacterium JCVI-Syn3A   112     0      0  346
# 3               Bacteroides thetaiotaomicron VPI-5482   282   107   4393   43
# 4   Salmonella enterica subsp. enterica serovar Ty...    78   493   4868   35
# 5   Escherichia coli K-12 BW25113+Escherichia coli...   946  1069  16830  538
# 6                       Escherichia coli K-12 BW25113   269   519   3496   29
# 7                        Escherichia coli K-12 MG1655   280   517   3506   10
# 8                      synthetic bacterium JCVI-Syn3A   259     0      0  199
# 9               Bacteroides thetaiotaomicron VPI-5482   292   622   3878   33
# 10  Salmonella enterica subsp. enterica serovar Ty...    65   688   4673   48
# 11  Escherichia coli K-12 BW25113+Escherichia coli...  1165  2346  15553  319
# 12                      Escherichia coli K-12 BW25113   270   430   3585   28
# 13                       Escherichia coli K-12 MG1655   282   440   3583    8
# 14                     synthetic bacterium JCVI-Syn3A   283     0      0  175
# 15              Bacteroides thetaiotaomicron VPI-5482   219   617   3883  106
# 16  Salmonella enterica subsp. enterica serovar Ty...    39   730   4631   74
# 17  Escherichia coli K-12 BW25113+Escherichia coli...  1093  2217  15682  391
# 18                      Escherichia coli K-12 BW25113   269   372   3643   29
# 19                       Escherichia coli K-12 MG1655   283   369   3654    7
# 20                     synthetic bacterium JCVI-Syn3A   305     0      0  153
# 21              Bacteroides thetaiotaomicron VPI-5482   257   529   3971   68
# 22  Salmonella enterica subsp. enterica serovar Ty...    36   651   4710   77
# 23  Escherichia coli K-12 BW25113+Escherichia coli...  1150  1921  15978  334
#
#          mcc       acc        f1       prc       rec       npv       tnr  \
# 0   0.594411  0.931834  0.613158  0.504329  0.781879  0.983121  0.942964
# 1   0.613699  0.932993  0.625162  0.501040  0.831034  0.987213  0.940343
# 2   0.000000  0.244541  0.392982  1.000000  0.244541  0.000000  0.000000
# 3   0.776919  0.968912  0.789916  0.724936  0.867692  0.990307  0.976222
# 4   0.278314  0.903544  0.228070  0.136602  0.690265  0.992862  0.908040
# 5   0.503330  0.917092  0.540726  0.469479  0.637466  0.969023  0.940276
# 6   0.507602  0.872942  0.495396  0.341371  0.902685  0.991773  0.870735
# 7   0.540069  0.877811  0.515179  0.351317  0.965517  0.997156  0.871489
# 8   0.000000  0.565502  0.722455  1.000000  0.565502  0.000000  0.000000
# 9   0.486274  0.864249  0.471348  0.319475  0.898462  0.991562  0.861778
# 10  0.184478  0.865546  0.150115  0.086321  0.575221  0.989833  0.871666
# 11  0.451501  0.862508  0.466466  0.331814  0.785040  0.979902  0.868931
# 12  0.549519  0.893809  0.541082  0.385714  0.906040  0.992250  0.892902
# 13  0.578935  0.896128  0.557312  0.390582  0.972414  0.997772  0.890629
# 14  0.000000  0.617904  0.763833  1.000000  0.617904  0.000000  0.000000
# 15  0.355445  0.850155  0.377261  0.261962  0.673846  0.973427  0.862889
# 16  0.085505  0.853124  0.088435  0.050715  0.345133  0.984272  0.863831
# 17  0.432902  0.865449  0.455987  0.330211  0.736523  0.975673  0.876138
# 18  0.577528  0.907025  0.572950  0.419657  0.902685  0.992102  0.907347
# 19  0.618118  0.912822  0.600849  0.434049  0.975862  0.998088  0.908277
# 20  0.000000  0.665939  0.799476  1.000000  0.665939  0.000000  0.000000
# 21  0.456933  0.876269  0.462646  0.326972  0.790769  0.983164  0.882444
# 22  0.084616  0.867008  0.090000  0.052402  0.318584  0.983915  0.878567
# 23  0.486138  0.883661  0.504940  0.374471  0.774933  0.979524  0.892676
#
#      auc-roc    auc-pr
# 0   0.910965  0.586572
# 1   0.947629  0.632228
# 2        NaN       NaN
# 3   0.975421  0.818815
# 4   0.891886  0.107095
# 5   0.883538  0.461305
# 6   0.942126  0.701041
# 7   0.975500  0.784774
# 8        NaN       NaN
# 9   0.937444  0.613368
# 10  0.832666  0.062933
# 11  0.894743  0.483360
# 12  0.950126  0.758463
# 13  0.980791  0.839553
# 14       NaN       NaN
# 15  0.851592  0.484393
# 16  0.717901  0.042231
# 17  0.880059  0.490736
# 18  0.947590  0.696496
# 19  0.981808  0.825065
# 20       NaN       NaN
# 21  0.918049  0.616563
# 22  0.781696  0.047115
# 23  0.900482  0.525443
